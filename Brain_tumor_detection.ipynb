# %%
import os
import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder()
encoder.fit([[0], [1]])
# Out:
# OneHotEncoder()

# %%
OneHotEncoder()
# Out:
# OneHotEncoder()

# %%
data = []
paths = []
result = []

for r, d, f in os.walk('/content/drive/MyDrive/brain_tumor_dataset/yes'):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[0]]).toarray())

# %%
paths = []
for r, d, f in os.walk('/content/drive/MyDrive/brain_tumor_dataset/no'):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[1]]).toarray())

# %%
data = np.array(data)
data.shape
# Out:
# (139, 128, 128, 3)

# %%
result = np.array(result)
result = result.reshape(139,2)

# %%
x_train,x_test,y_train,y_test = train_test_split(data, result, test_size=0.2, shuffle=True, random_state=0)

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(2, 2), input_shape=(128, 128, 3), padding = 'Same'))
model.add(Conv2D(32, kernel_size=(2, 2),  activation ='relu', padding = 'Same'))


model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))

model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

# model.compile(loss = "categorical_crossentropy", optimizer='Adamax')
model.compile(loss="categorical_crossentropy", optimizer="Adamax", metrics=["accuracy"])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      416
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      4128
#
#  batch_normalization (Batch  (None, 128, 128, 32)      128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 64, 64, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)        8256
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 64)        16448
#
#  batch_normalization_1 (Bat  (None, 64, 64, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 32, 32, 64)        0
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 512)               33554944
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 33585602 (128.12 MB)
# Trainable params: 33585410 (128.12 MB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________
# None

# %%
y_train.shape
# Out:
# (111, 2)

# %%
history = model.fit(x_train, y_train, epochs = 30, batch_size = 40, verbose = 1,validation_data = (x_test, y_test))
# Out:
# Epoch 1/30
# 3/3 [==============================] - 11s 3s/step - loss: 15.1694 - accuracy: 0.6216 - val_loss: 59.0038 - val_accuracy: 0.4643
# Epoch 2/30
# 3/3 [==============================] - 11s 3s/step - loss: 22.3892 - accuracy: 0.6216 - val_loss: 32.1255 - val_accuracy: 0.4643
# Epoch 3/30
# 3/3 [==============================] - 10s 4s/step - loss: 12.2230 - accuracy: 0.7117 - val_loss: 33.4945 - val_accuracy: 0.5000
# Epoch 4/30
# 3/3 [==============================] - 9s 3s/step - loss: 4.3703 - accuracy: 0.8559 - val_loss: 7.1496 - val_accuracy: 0.7500
# Epoch 5/30
# 3/3 [==============================] - 11s 4s/step - loss: 2.5560 - accuracy: 0.8739 - val_loss: 8.0116 - val_accuracy: 0.7500
# Epoch 6/30
# 3/3 [==============================] - 8s 3s/step - loss: 0.9514 - accuracy: 0.9369 - val_loss: 16.5322 - val_accuracy: 0.5357
# Epoch 7/30
# 3/3 [==============================] - 11s 4s/step - loss: 1.5027 - accuracy: 0.8919 - val_loss: 19.9922 - val_accuracy: 0.5357
# Epoch 8/30
# 3/3 [==============================] - 9s 3s/step - loss: 1.5789 - accuracy: 0.9640 - val_loss: 9.4814 - val_accuracy: 0.6786
# Epoch 9/30
# 3/3 [==============================] - 11s 3s/step - loss: 0.5591 - accuracy: 0.9640 - val_loss: 5.3259 - val_accuracy: 0.7857
# Epoch 10/30
# 3/3 [==============================] - 12s 4s/step - loss: 0.1916 - accuracy: 0.9730 - val_loss: 3.5821 - val_accuracy: 0.7500
# Epoch 11/30
# 3/3 [==============================] - 9s 3s/step - loss: 0.6953 - accuracy: 0.9640 - val_loss: 4.1726 - val_accuracy: 0.7500
# Epoch 12/30
# 3/3 [==============================] - 11s 4s/step - loss: 0.2742 - accuracy: 0.9550 - val_loss: 3.5373 - val_accuracy: 0.7857
# Epoch 13/30
# 3/3 [==============================] - 8s 3s/step - loss: 0.0713 - accuracy: 0.9910 - val_loss: 3.6468 - val_accuracy: 0.8571
# Epoch 14/30
# 3/3 [==============================] - 11s 4s/step - loss: 0.3083 - accuracy: 0.9730 - val_loss: 3.3209 - val_accuracy: 0.7500
# Epoch 15/30
# 3/3 [==============================] - 9s 3s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 3.5031 - val_accuracy: 0.7500
# Epoch 16/30
# 3/3 [==============================] - 10s 3s/step - loss: 0.0600 - accuracy: 0.9820 - val_loss: 4.0566 - val_accuracy: 0.7500
# Epoch 17/30
# 3/3 [==============================] - 10s 4s/step - loss: 0.2182 - accuracy: 0.9640 - val_loss: 3.5979 - val_accuracy: 0.7500
# Epoch 18/30
# 3/3 [==============================] - 9s 3s/step - loss: 0.0509 - accuracy: 0.9910 - val_loss: 3.1534 - val_accuracy: 0.7143
# Epoch 19/30
# 3/3 [==============================] - 11s 4s/step - loss: 0.1561 - accuracy: 0.9820 - val_loss: 3.3467 - val_accuracy: 0.8571
# Epoch 20/30
# 3/3 [==============================] - 8s 3s/step - loss: 1.2887e-08 - accuracy: 1.0000 - val_loss: 4.0672 - val_accuracy: 0.8214
# Epoch 21/30
# 3/3 [==============================] - 11s 4s/step - loss: 2.2115e-04 - accuracy: 1.0000 - val_loss: 4.5819 - val_accuracy: 0.8214
# Epoch 22/30
# 3/3 [==============================] - 9s 3s/step - loss: 0.4476 - accuracy: 0.9730 - val_loss: 4.3102 - val_accuracy: 0.8214
# Epoch 23/30
# 3/3 [==============================] - 10s 3s/step - loss: 1.0417e-07 - accuracy: 1.0000 - val_loss: 3.6068 - val_accuracy: 0.8214
# Epoch 24/30
# 3/3 [==============================] - 10s 4s/step - loss: 5.3671e-06 - accuracy: 1.0000 - val_loss: 3.2268 - val_accuracy: 0.8571
# Epoch 25/30
# 3/3 [==============================] - 8s 3s/step - loss: 7.0422e-05 - accuracy: 1.0000 - val_loss: 3.0774 - val_accuracy: 0.7857
# Epoch 26/30
# 3/3 [==============================] - 10s 4s/step - loss: 0.0185 - accuracy: 0.9910 - val_loss: 3.0918 - val_accuracy: 0.7857
# Epoch 27/30
# 3/3 [==============================] - 8s 3s/step - loss: 2.1530e-06 - accuracy: 1.0000 - val_loss: 3.1151 - val_accuracy: 0.7857
# Epoch 28/30
# 3/3 [==============================] - 10s 3s/step - loss: 0.1451 - accuracy: 0.9910 - val_loss: 3.2089 - val_accuracy: 0.7143
# Epoch 29/30
# 3/3 [==============================] - 10s 4s/step - loss: 0.3696 - accuracy: 0.9910 - val_loss: 3.3253 - val_accuracy: 0.7143
# Epoch 30/30
# 3/3 [==============================] - 9s 3s/step - loss: 0.3350 - accuracy: 0.9820 - val_loss: 3.4352 - val_accuracy: 0.8571

# %%
#trained model, 'x_test', 'y_test' are test data
evaluation_results = model.evaluate(x_test, y_test)

# 'evaluate' method returns a list of metrics, including accuracy
accuracy = evaluation_results[1]

print("Model Accuracy on Test Set: {:.2f}%".format(accuracy * 100))
# Out:
# 1/1 [==============================] - 1s 783ms/step - loss: 3.4352 - accuracy: 0.8571
# Model Accuracy on Test Set: 85.71%

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Test', 'Validation'], loc='upper right')
plt.show()

# %%
def names(number):
    if number==0:
        return 'Its a Tumor'
    else:
        return 'No, Its not a tumor'

# %%
from matplotlib.pyplot import imshow
img = Image.open("/content/drive/MyDrive/brain_tumor_dataset/no/14 no.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is ' + names(classification))
# Out:
# 100.0% Confidence This Is No, Its not a tumor

# %%
from matplotlib.pyplot import imshow
img = Image.open("/content/drive/MyDrive/brain_tumor_dataset/yes/Y103.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is A ' + names(classification))
# Out:
# 100.0% Confidence This Is A Its a Tumor

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# 'x_test', 'y_test' are test data
y_pred = model.predict(x_test)

# Convert probabilities to class labels (assuming binary classification)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Calculate precision, recall, and F1 score
precision = precision_score(y_true_classes, y_pred_classes)
recall = recall_score(y_true_classes, y_pred_classes)
f1 = f1_score(y_true_classes, y_pred_classes)

print("Precision: {:.2f}".format(precision))
print("Recall: {:.2f}".format(recall))
print("F1 Score: {:.2f}".format(f1))
# Out:
# 1/1 [==============================] - 1s 928ms/step
# Precision: 0.92
# Recall: 0.79
# F1 Score: 0.85
